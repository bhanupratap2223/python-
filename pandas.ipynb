# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\sanja\\OneDrive\\Desktop\\gdp.csv")

# %%
df
# Out:
#      Index Number  Rank                                Country/Economy  \
# 0              NaN  NaN                                            NaN
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# ...

# %%
df.tail()
# Out:
#      Index Number  Rank                                Country/Economy  \
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# 226                   -               -          -          -        -
# 227                   -               -          -          -        -
# 228                   -               -          -        0.5        -
# 229                   -               -          -          -        -
# 230                   -               -          -          -        -
#
#     Unnamed: 8 Unnamed: 9 Services Unnamed: 11 Unnamed: 12 Year GDP   \
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Index Number ', 'Rank', 'Country/Economy', 'GDP (millions of $)',
#        'Agriculture GDP', 'Unnamed: 5', 'Unnamed: 6', 'Industry', 'Unnamed: 8',
#        'Unnamed: 9', 'Services', 'Unnamed: 11', 'Unnamed: 12', 'Year GDP ',
#        'Year Sector'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 0            NaN  NaN             NaN                 NaN             GDP
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  Services Unnamed: 11  \
# 0       Rank   % of GDP      GDP       Rank   % of GDP       GDP        Rank
# 1          3        0.9  3659040          2       18.9  15526720           1
# 2          1        8.3  4716300          1       39.5   6232680           2
#
#   Unnamed: 12 Year GDP  Year Sector
# 0    % of GDP       NaN         NaN
# 1        80.2      2017        2017
# 2        52.2      2017        2017

# %%
df.dtypes
# Out:
# Index Number           float64
# Rank                    object
# Country/Economy         object
# GDP (millions of $)     object
# Agriculture GDP         object
# Unnamed: 5              object
# Unnamed: 6              object
# Industry                object
# Unnamed: 8              object
# Unnamed: 9              object
# Services                object
# Unnamed: 11             object
# Unnamed: 12             object
# Year GDP                object
# Year Sector             object
# dtype: object

# %%
df['Services']
print(df,end=' ')
# Out:
#      Index Number  Rank                                Country/Economy  \
# 0              NaN  NaN                                            NaN
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# ...

# %%
list(df['Services'])
# Out:
# ['GDP',
#  '15526720',
#  '6232680',
#  '3384612',
#  '2530836',
#  '2005925',
#  '2062260',
#  '1499985',
#  '1514968',
#  '1419619',
#  '1151280',
#  '891990',
#  '915187',
#  '977170',
#  '969794',
#  '730880',
#  '423795',
#  '516497',
#  '578799',
#  '363728',
#  '501602',
#  '377519',
#  '354902',
#  '354403',
#  '292740',
#  '381068',
#  '243417',
#  '232241',
#  '288147',
#  '237275',
#  '260747',
#  '186320',
#  '241860',
#  '232268',
#  '316478',
#  '197639',
#  '243723',
#  '187413',
#  '169515',
#  '188805',
#  '229962',
#  '157021',
#  '169238',
#  '175488',
#  '139329',
#  '92223',
#  '123582',
#  '160257',
#  '117810',
#  '125191',
#  '128267',
#  '163440',
#  '140359',
#  '107891',
#  '105214',
#  '88979',
#  '82319',
#  '94970',
#  '85404',
#  '35216',
#  '68782',
#  '48385',
#  '61992',
#  '60586',
#  '50671',
#  '57412',
#  '58140',
#  '69592',
#  '51563',
#  '33491',
#  '37501',
#  '45521',
#  '38123',
#  '44752',
#  '31730',
#  '26721',
#  '55834',
#  '41466',
# ...

# %%
df[['Agriculture GDP','Rank']]
# Out:
#     Agriculture GDP Rank
# 0               GDP  NaN
# 1            174240    1
# 2            991020    2
# 3             48840    3
# 4             21912    4
# ..              ...  ...
# 226               -    -
# 227               -    -
# 228               -    -
# 229               -    -
# 230               -    -
#
# [231 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Index Number ', 'Rank', 'Country/Economy', 'GDP (millions of $)',
#        'Agriculture GDP', 'Unnamed: 5', 'Unnamed: 6', 'Industry', 'Unnamed: 8',
#        'Unnamed: 9', 'Services', 'Unnamed: 11', 'Unnamed: 12', 'Year GDP ',
#        'Year Sector'],
#       dtype='object')

# %%
import lxml 
import pandas  as pd
A=pd.read_html('https://www.basketball-reference.com/')

# %%
type(A)
# Out:
# list

# %%
A
# Out:
# [        East Unnamed: 1 Unnamed: 2   W   L
#  0    MIL (1)          F          $  52  20
#  1    BOS (2)          F          $  50  23
#  2    PHI (3)          F          $  49  23
#  3    CLE (4)          F          $  46  28
#  4    NYK (5)          F          $  42  32
#  5    BRK (6)          F          $  39  33
#  6    MIA (7)          F          $  40  34
#  7    ATL (8)          F          $  36  37
#  8    TOR (9)          F          $  35  38
#  9   CHI (10)          F          $  34  38
#  10  IND (11)          F          $  33  40
#  11  WAS (12)          F          $  32  41
#  12  ORL (13)          F          $  30  43
#  13  CHO (14)          F          $  23  50
#  14  DET (15)          F          $  16  57,
#          West Unnamed: 1 Unnamed: 2   W   L
#  0    DEN (1)          F          $  49  24
#  1    MEM (2)          F          $  45  27
#  2    SAC (3)          F          $  43  29
#  3    PHO (4)          F          $  38  34
# ...

# %%
df.head(2)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 0            NaN  NaN             NaN                 NaN             GDP
# 1            0.0    1   United States            19360000          174240
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  Services Unnamed: 11  \
# 0       Rank   % of GDP      GDP       Rank   % of GDP       GDP        Rank
# 1          3        0.9  3659040          2       18.9  15526720           1
#
#   Unnamed: 12 Year GDP  Year Sector
# 0    % of GDP       NaN         NaN
# 1        80.2      2017        2017

# %%
df.describe()
# Out:
#        Index Number
# count     230.000000
# mean      114.500000
# std        66.539462
# min         0.000000
# 25%        57.250000
# 50%       114.500000
# 75%       171.750000
# max       229.000000

# %%
df[['Rank','Industry']]
# Out:
#     Rank Industry
# 0    NaN      GDP
# 1      1  3659040
# 2      2  4716300
# 3      3  1450548
# 4      4  1099252
# ..   ...      ...
# 226    -        -
# 227    -        -
# 228    -        -
# 229    -        -
# 230    -        -
#
# [231 rows x 2 columns]

# %%
df.dtypes== 'object'
# Out:
# Index Number           False
# Rank                    True
# Country/Economy         True
# GDP (millions of $)     True
# Agriculture GDP         True
# Unnamed: 5              True
# Unnamed: 6              True
# Industry                True
# Unnamed: 8              True
# Unnamed: 9              True
# Services                True
# Unnamed: 11             True
# Unnamed: 12             True
# Year GDP                True
# Year Sector             True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Rank', 'Country/Economy', 'GDP (millions of $)', 'Agriculture GDP',
#        'Unnamed: 5', 'Unnamed: 6', 'Industry', 'Unnamed: 8', 'Unnamed: 9',
#        'Services', 'Unnamed: 11', 'Unnamed: 12', 'Year GDP ', 'Year Sector'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#        Rank Country/Economy GDP (millions of $) Agriculture GDP Unnamed: 5  \
# count   230             230                 230             231        231
# unique  225             230                 225             209        220
# top       -   United States                   -               -          -
# freq      6               1                   6              12         12
#
#        Unnamed: 6 Industry Unnamed: 8 Unnamed: 9 Services Unnamed: 11  \
# count         231      231        231        231      231         231
# unique        151      218        222        173      221         223
# top             -        -          -          -        -           -
# freq            6       10         10          7        9           9
#
#        Unnamed: 12 Year GDP  Year Sector
# count          231       230         230
# unique         179        11          17
# top              -      2017        2017
# freq             6       189         184

# %%
df[['Rank','Agriculture GDP']][7:15:2]
# Out:
#    Rank Agriculture GDP
# 7     7          375606
# 9     9           40341
# 11   11           33660
# 13   13           50040

# %%
df['new_col']= 0

# %%
df.head(3)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 0            NaN  NaN             NaN                 NaN             GDP
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  Services Unnamed: 11  \
# 0       Rank   % of GDP      GDP       Rank   % of GDP       GDP        Rank
# 1          3        0.9  3659040          2       18.9  15526720           1
# 2          1        8.3  4716300          1       39.5   6232680           2
#
#   Unnamed: 12 Year GDP  Year Sector  new_col
# 0    % of GDP       NaN         NaN        0
# 1        80.2      2017        2017        0
# 2        52.2      2017        2017        0

# %%
pd.Categorical(df['Rank'])
# Out:
# [NaN, '1', '2', '3', '4', ..., '-', '-', '-', '-', '-']
# Length: 231
# Categories (225, object): ['-', '1', '10', '100', ..., '96', '97', '98', '99']

# %%
df['Rank'].unique
# Out:
# <bound method Series.unique of 0      NaN
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 226      -
# 227      -
# 228      -
# 229      -
# 230      -
# Name: Rank, Length: 231, dtype: object>

# %%
df[df['Rank']]==4
# Out:
#       NaN     1     2     3     4     5     6     7     8     9  ...   221  \
# 0    True  True  True  True  True  True  True  True  True  True  ...  True
# 1    True  True  True  True  True  True  True  True  True  True  ...  True
# 2    True  True  True  True  True  True  True  True  True  True  ...  True
# 3    True  True  True  True  True  True  True  True  True  True  ...  True
# 4    True  True  True  True  True  True  True  True  True  True  ...  True
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 226  True  True  True  True  True  True  True  True  True  True  ...  True
# 227  True  True  True  True  True  True  True  True  True  True  ...  True
# 228  True  True  True  True  True  True  True  True  True  True  ...  True
# 229  True  True  True  True  True  True  True  True  True  True  ...  True
# 230  True  True  True  True  True  True  True  True  True  True  ...  True
#
#       222   223   224     -     -     -     -     -     -
# ...

# %%
df['Country/Economy']=='india'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# Name: Country/Economy, Length: 231, dtype: bool

# %%
df.loc[0:3]
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 0            NaN  NaN             NaN                 NaN             GDP
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
# 3            2.0    3           Japan             4884000           48840
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  ... 216 217 218 219  \
# 0       Rank   % of GDP      GDP       Rank   % of GDP  ...   4   4   4   4
# 1          3        0.9  3659040          2       18.9  ...   4   4   4   4
# 2          1        8.3  4716300          1       39.5  ...   4   4   4   4
# 3         13          1  1450548          3       29.7  ...   4   4   4   4
#
#   220  221  222  223  224  -
# 0   4    4    4    4    4  4
# 1   4    4    4    4    4  4
# 2   4    4    4    4    4  4
# 3   4    4    4    4    4  4
#
# [4 rows x 241 columns]

# %%
df.iloc[0:3]
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 0            NaN  NaN             NaN                 NaN             GDP
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  ... 216 217 218 219  \
# 0       Rank   % of GDP      GDP       Rank   % of GDP  ...   4   4   4   4
# 1          3        0.9  3659040          2       18.9  ...   4   4   4   4
# 2          1        8.3  4716300          1       39.5  ...   4   4   4   4
#
#   220  221  222  223  224  -
# 0   4    4    4    4    4  4
# 1   4    4    4    4    4  4
# 2   4    4    4    4    4  4
#
# [3 rows x 241 columns]

# %%
new_df=df.dropna()

# %% [markdown]
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.

# %%
new_df
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# ...

# %% [markdown]
# Remove all rows with NULL values:

# %%
df.dropna(inplace= True)
print(df)
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# ...

# %%
df.drop("Agriculture GDP",axis= 1)
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  \
# ...

# %%
df.drop("Agriculture GDP",axis= 1, inplace= True)

# %%
df
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  \
# ...

# %%
df.drop(3)
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# 6              5.0    6                                 United Kingdom
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  \
# ...

# %%
d= { "key1" : [1,5,7,8,9,2],
     "key2" : [4,5,6,8,9,8],
     "key3": [5,6,9,8,7,5]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     5
# 1     5     5     6
# 2     7     6     9
# 3     8     8     8
# 4     9     9     7
# 5     2     8     5

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     5
# 1     5     5     6
# 2     7     6     9
# 3     8     8     8
# 4     9     9     7
# 5     2     8     5

# %%
df.dropna()
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  \
# ...

# %%
new_df.fillna("shambhu")
# Out:
#      Index Number  Rank                                Country/Economy  \
# 1              0.0    1                                  United States
# 2              1.0    2                                          China
# 3              2.0    3                                          Japan
# 4              3.0    4                                        Germany
# 5              4.0    5                                         France
# ..             ...  ...                                            ...
# 226          225.0    -  Saint Helena, Ascension, and Tristan da Cunha
# 227          226.0    -                                        Tokelau
# 228          227.0    -                       Turks and Caicos Islands
# 229          228.0    -                              Wallis and Futuna
# 230          229.0    -                                 Western Sahara
#
#     GDP (millions of $) Agriculture GDP Unnamed: 5 Unnamed: 6 Industry  \
# ...

# %%
new_df.loc[7,'Rank']=5

# %% [markdown]
# Set "Rank" = 5 in row 7:

# %%
new_df.head(8)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
# 3            2.0    3           Japan             4884000           48840
# 4            3.0    4         Germany             3652000           21912
# 5            4.0    5          France             2575000           51500
# 6            5.0    6  United Kingdom             2565000           15390
# 7            6.0    5           India             2439000          375606
# 8            7.0    8          Brazil             2081000          129022
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  ... 216 217 218 219  \
# 1          3        0.9  3659040          2       18.9  ...   4   4   4   4
# 2          1        8.3  4716300          1       39.5  ...   4   4   4   4
# ...

# %%
new_df.loc[7,'Country/Economy']='india'

# %%
new_df.head(7)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
# 3            2.0    3           Japan             4884000           48840
# 4            3.0    4         Germany             3652000           21912
# 5            4.0    5          France             2575000           51500
# 6            5.0    6  United Kingdom             2565000           15390
# 7            6.0    5           india             2439000          375606
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  ... 216 217 218 219  \
# 1          3        0.9  3659040          2       18.9  ...   4   4   4   4
# 2          1        8.3  4716300          1       39.5  ...   4   4   4   4
# 3         13          1  1450548          3       29.7  ...   4   4   4   4
# ...

# %%
for x in new_df.index:
    if new_df.loc[x, "Country/Economy"]==5:
        df.drop(x, inplace= True)

# %%
new_df.head(7)
# Out:
#    Index Number  Rank Country/Economy GDP (millions of $) Agriculture GDP  \
# 1            0.0    1   United States            19360000          174240
# 2            1.0    2           China            11940000          991020
# 3            2.0    3           Japan             4884000           48840
# 4            3.0    4         Germany             3652000           21912
# 5            4.0    5          France             2575000           51500
# 6            5.0    6  United Kingdom             2565000           15390
# 7            6.0    5           india             2439000          375606
#
#   Unnamed: 5 Unnamed: 6 Industry Unnamed: 8 Unnamed: 9  ... 216 217 218 219  \
# 1          3        0.9  3659040          2       18.9  ...   4   4   4   4
# 2          1        8.3  4716300          1       39.5  ...   4   4   4   4
# 3         13          1  1450548          3       29.7  ...   4   4   4   4
# ...

# %%
new_df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# Length: 230, dtype: bool

# %%
new_df.head(125).duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# Length: 125, dtype: bool
